# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#        Unnamed: 0  ODATEDW  TCODE   DOB        AGE  INCOME  WEALTH1  HIT  \
# 0               0     8901      0  3712  60.000000     0.0      NaN    0
# 1               1     9401      1  5202  46.000000     6.0      9.0   16
# 2               2     9001      1     0  61.611649     3.0      1.0    2
# 3               3     8701      0  2801  70.000000     1.0      4.0    2
# 4               4     8601      0  2001  78.000000     3.0      2.0   60
# ...           ...      ...    ...   ...        ...     ...      ...  ...
# 95407       95407     9601      1     0  61.611649     0.0      NaN    0
# 95408       95408     9601      1  5001  48.000000     7.0      9.0    1
# 95409       95409     9501      1  3801  60.000000     0.0      NaN    0
# 95410       95410     8601      0  4005  58.000000     7.0      NaN    0
# 95411       95411     8801      2  1801  80.000000     5.0      8.0    3
#
#        MALEMILI  MALEVET  ...  LASTGIFT  LASTDATE  FISTDATE  NEXTDATE  \
# ...

# %%
numerical = data.select_dtypes(np.number)

# %%
numerical
# Out:
#        Unnamed: 0  ODATEDW  TCODE   DOB        AGE  INCOME  WEALTH1  HIT  \
# 0               0     8901      0  3712  60.000000     0.0      NaN    0
# 1               1     9401      1  5202  46.000000     6.0      9.0   16
# 2               2     9001      1     0  61.611649     3.0      1.0    2
# 3               3     8701      0  2801  70.000000     1.0      4.0    2
# 4               4     8601      0  2001  78.000000     3.0      2.0   60
# ...           ...      ...    ...   ...        ...     ...      ...  ...
# 95407       95407     9601      1     0  61.611649     0.0      NaN    0
# 95408       95408     9601      1  5001  48.000000     7.0      9.0    1
# 95409       95409     9501      1  3801  60.000000     0.0      NaN    0
# 95410       95410     8601      0  4005  58.000000     7.0      NaN    0
# 95411       95411     8801      2  1801  80.000000     5.0      8.0    3
#
#        MALEMILI  MALEVET  ...  LASTGIFT  LASTDATE  FISTDATE  NEXTDATE  \
# ...

# %%
data = pd.DataFrame(numerical.isna().sum()).reset_index()
data.columns = ['columns_name', 'nulls']
data[data['nulls'] > 0]
# Out:
#     columns_name  nulls
# 6        WEALTH1  44732
# 136          MSA    132
# 137          ADI    132
# 138          DMA    132
# 316     NEXTDATE   9973

# %%
numerical['WEALTH1'].value_counts()
numerical['WEALTH1'] = numerical['WEALTH1'].fillna('9')

# %%
numerical['ADI'].value_counts()
numerical['ADI'] = numerical['ADI'].fillna(round(numerical['ADI'].mean()))

# %%
numerical['DMA'].value_counts()
numerical['DMA'] = numerical['DMA'].fillna(round(numerical['DMA'].mean()))

# %%
numerical['MSA'].value_counts()
numerical['MSA'] = numerical['MSA'].fillna(round(numerical['MSA'].mean()))

# %%
numerical = numerical.drop(columns = ['NEXTDATE'])

# %%
categorical = pd.read_csv('categorical.csv')

# %%
categorical['GEOCODE2'].isnull().sum()
# Out:
# 0

# %%
data = pd.DataFrame(categorical.isna().sum()).reset_index()
data.columns = ['columns_name', 'nulls']
data[data['nulls'] > 0]
# Out:
#   columns_name  nulls
# 1      OSOURCE    928
# 6       GENDER   2957
# 8        SOLIH  89212
# 9     VETERANS  84986

# %%
categorical = categorical.drop(columns = ['OSOURCE'])
categorical = categorical.drop(columns = ['GENDER'])
categorical = categorical.drop(columns = ['SOLIH'])
categorical = categorical.drop(columns = ['VETERANS'])

# %%
categorical.to_csv('categorical_clean.csv')

# %%
numerical.to_csv('numerical_clean.csv')
