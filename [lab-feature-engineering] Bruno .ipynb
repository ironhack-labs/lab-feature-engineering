# %%
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\btdjf\Desktop\Ironhack 2\Lab Feature Engineering\lab-feature-engineering\learningSet.txt")
data
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# ...

# %%
nulls = data.isna().sum()
nulls
# Out:
# ODATEDW       0
# OSOURCE       0
# TCODE         0
# STATE         0
# ZIP           0
#            ...
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# CLUSTER2    132
# GEOCODE2    132
# Length: 481, dtype: int64

# %%
data['GEOCODE2'].value_counts()
# Out:
# GEOCODE2
# A    34484
# B    28505
# D    16580
# C    15524
#        187
# Name: count, dtype: int64

# %%
data['WEALTH1'].value_counts()
# Out:
# WEALTH1
# 9.0    7585
# 8.0    6793
# 7.0    6198
# 6.0    5825
# 5.0    5280
# 4.0    4810
# 3.0    4237
# 2.0    4085
# 1.0    3454
# 0.0    2413
# Name: count, dtype: int64

# %%
data['ADI'].value_counts()
# Out:
# ADI
# 13.0     7296
# 51.0     4622
# 65.0     3765
# 57.0     2836
# 105.0    2617
#          ...
# 651.0       1
# 103.0       1
# 601.0       1
# 161.0       1
# 147.0       1
# Name: count, Length: 204, dtype: int64

# %%
data['DMA'].value_counts()
# Out:
# DMA
# 803.0    7296
# 602.0    4632
# 807.0    3765
# 505.0    2839
# 819.0    2588
#          ...
# 569.0       1
# 554.0       1
# 584.0       1
# 552.0       1
# 516.0       1
# Name: count, Length: 206, dtype: int64

# %%
data['MSA'].value_counts()
# Out:
# MSA
# 0.0       21333
# 4480.0     4606
# 1600.0     4059
# 2160.0     2586
# 520.0      1685
#           ...
# 9140.0        1
# 3200.0        1
# 9280.0        1
# 743.0         1
# 8480.0        1
# Name: count, Length: 298, dtype: int64

# %%
sns.distplot(data['WEALTH1'])
plt.show()

data['WEALTH1'] = data['WEALTH1'].fillna('9.0')

sns.distplot(data['WEALTH1'])
plt.show()

# %%
sns.distplot(data['ADI'])
plt.show()

data['ADI'] = data['ADI'].fillna(np.mean(data['ADI']))

sns.distplot(data['ADI'])
plt.show()

# %%
sns.distplot(data['DMA'])
plt.show()

data['DMA'] = data['DMA'].fillna(np.mean(data['DMA']))

sns.distplot(data['DMA'])
plt.show()

# %%
sns.distplot(data['MSA'])
plt.show()

data['MSA'] = data['MSA'].fillna(np.mean(data['MSA']))

sns.distplot(data['MSA'])
plt.show()

# %%
sns.histplot(data['GEOCODE2'])
plt.show()
