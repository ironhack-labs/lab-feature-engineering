# %%
#Lab | Feature engineering

#In this lab, you will use learningSet.csv file which you have already cloned in the previous activities.
#Instructions
#Here we will work on cleaning some of the other columns in the dataset using the techniques that we used before in the lessons.

#Check for null values in the numerical columns.
#Use appropriate methods to clean the columns GEOCODE2, WEALTH1, ADI, DMA,and MSA.
#Use appropriate EDA technique where ever necessary.

# %%
import pandas as pd

# %%
data_numerical = pd.read_csv('numerical_lab_feature_engineering.csv')

# %%
data_categorical = pd.read_csv('categorical_lab_feature_engineering.csv')

# %%
data_categorical
# Out:
#       OSOURCE  STATE    ZIP DOMAIN  CLUSTER HOMEOWNR GENDER DATASRCE  SOLIH  \
# 0         GRI     IL  61081     T2       36        U      F        C    NaN
# 1         BOA     CA  91326     S1       14        H      M        A    NaN
# 2         AMH     NC  27017     R2       43        U      M        C    NaN
# 3         BRY     CA  95953     R2       44        U      F        C    NaN
# 4         NaN     FL  33176     S2       16        H      F        A   12.0
# ...       ...    ...    ...    ...      ...      ...    ...      ...    ...
# 95407     ASE  other  99504     C2       27        U      M        C    NaN
# 95408     DCD     TX  77379     C1       24        H      M        A    NaN
# 95409     MBC     MI  48910     C3       30        U      M        B    NaN
# 95410     PRV     CA  91320     C1       24        H      F        A   12.0
# 95411     MCC     NC  28409     C1       24        U      F        C   12.0
#
# ...

# %%
data_numerical
# Out:
#        ODATEDW  TCODE   DOB        AGE  INCOME  WEALTH1  HIT  MALEMILI  \
# 0         8901      0  3712  60.000000     0.0      NaN    0         0
# 1         9401      1  5202  46.000000     6.0      9.0   16         0
# 2         9001      1     0  61.611649     3.0      1.0    2         0
# 3         8701      0  2801  70.000000     1.0      4.0    2         0
# 4         8601      0  2001  78.000000     3.0      2.0   60         1
# ...        ...    ...   ...        ...     ...      ...  ...       ...
# 95407     9601      1     0  61.611649     0.0      NaN    0        14
# 95408     9601      1  5001  48.000000     7.0      9.0    1         0
# 95409     9501      1  3801  60.000000     0.0      NaN    0         0
# 95410     8601      0  4005  58.000000     7.0      NaN    0         0
# 95411     8801      2  1801  80.000000     5.0      8.0    3         1
#
#        MALEVET  VIETVETS  ...  LASTGIFT  LASTDATE  FISTDATE  NEXTDATE  \
# ...

# %%
data_numerical['WEALTH1'].value_counts()
# Out:
# 9.0    7585
# 8.0    6793
# 7.0    6198
# 6.0    5825
# 5.0    5280
# 4.0    4810
# 3.0    4237
# 2.0    4085
# 1.0    3454
# 0.0    2413
# Name: WEALTH1, dtype: int64

# %%
#Filling with the mode - WEALTH1

# %%
data_numerical['WEALTH1'] = data_numerical['WEALTH1'].fillna(9.0)

# %%
data_numerical['ADI'].value_counts()
# Out:
# 13.0     7296
# 51.0     4622
# 65.0     3765
# 57.0     2836
# 105.0    2617
#          ...
# 651.0       1
# 103.0       1
# 601.0       1
# 161.0       1
# 147.0       1
# Name: ADI, Length: 204, dtype: int64

# %%
data_numerical['DMA'].value_counts()
# Out:
# 803.0    7296
# 602.0    4632
# 807.0    3765
# 505.0    2839
# 819.0    2588
#          ...
# 569.0       1
# 554.0       1
# 584.0       1
# 552.0       1
# 516.0       1
# Name: DMA, Length: 206, dtype: int64

# %%
data_numerical['MSA'].value_counts()
# Out:
# 0.0       21333
# 4480.0     4606
# 1600.0     4059
# 2160.0     2586
# 520.0      1685
#           ...
# 9140.0        1
# 3200.0        1
# 9280.0        1
# 743.0         1
# 8480.0        1
# Name: MSA, Length: 298, dtype: int64

# %%
#The other 3 columns filling with the mean

# %%
data_numerical['ADI'] = data_numerical['ADI'].fillna(round(data_numerical['ADI'].mean()))

# %%
data_numerical['DMA'] = data_numerical['DMA'].fillna(round(data_numerical['DMA'].mean()))

# %%
data_numerical['MSA'] = data_numerical['MSA'].fillna(round(data_numerical['MSA'].mean()))

# %%
df = pd.DataFrame(data_numerical.isna().sum()).reset_index()
df.columns = ['column_name', 'nulls']
df[df['nulls']>0]
# Out:
#     column_name  nulls
# 315    NEXTDATE   9973

# %%
data_numerical = data_numerical.drop(['NEXTDATE'], axis=1)

# %%
df = pd.DataFrame(data_categorical.isna().sum()).reset_index()
df.columns = ['column_name', 'nulls']
df[df['nulls']>0]
# Out:
#    column_name  nulls
# 0      OSOURCE    928
# 6       GENDER   2957
# 8        SOLIH  89212
# 9     VETERANS  84986
# 13    GEOCODE2    319

# %%
data_categorical = data_categorical.drop(['OSOURCE', 'GENDER', 'SOLIH', 'VETERANS', 'GEOCODE2'], axis=1)

# %%
data_numerical.to_csv('numerical_clean_feature_engineering',index = False)
data_categorical.to_csv('categorical_clean_feature_engineering',index = False)
