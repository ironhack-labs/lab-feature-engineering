# %%
# Libraies
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Exercise: Clean dataset
# 1. Use appropriate methods to clean the columns GEOCODE2, WEALTH1, ADI, DMA,and MSA.

# %%
df = pd.read_csv(r'C:\Users\ljant\Desktop\Ironhack\15_Intro_ML\learningSet_3.txt')
df
# 95.412 x 385
# Out:
#        ODATEDW  TCODE STATE MAILCODE PVASTATE   DOB NOEXCH RECINHSE RECP3  \
# 0         8901      0    IL                    3712      0
# 1         9401      1    CA                    5202      0
# 2         9001      1    NC                       0      0
# 3         8701      0    CA                    2801      0
# 4         8601      0    FL                    2001      0        X     X
# ...        ...    ...   ...      ...      ...   ...    ...      ...   ...
# 95407     9601      1    AK                       0      0
# 95408     9601      1    TX                    5001      0
# 95409     9501      1    MI                    3801      0              X
# 95410     8601      0    CA                    4005      0        X
# 95411     8801      2    NC                    1801      0        X
#
#       RECPGVG  ... TARGET_D HPHONE_D RFA_2R RFA_2F  RFA_2A MDMAUD_R MDMAUD_F  \
# 0              ...      0.0        0      L      4       E        X        X
# ...

# %%
# Column 'GEOCODE2'
df['GEOCODE2'].value_counts()

# Filling NaNs (' ') with the mode ('A') 
df['GEOCODE2'].replace(' ', 'A', inplace = True)
df['GEOCODE2'].value_counts()
# Out:
# A    34671
# B    28505
# D    16580
# C    15524
# Name: GEOCODE2, dtype: int64

# %%
# 'WEALTH1' does not exist in the df

# %%
# Column 'ADI'
df['ADI'].unique
sns.distplot(df['ADI'])
plt.show()
df['ADI'].isna().sum()

# Fillining NaNs with the mean
df['ADI'] = df['ADI'].fillna(np.mean(df['ADI']))
sns.distplot(df['ADI'])
plt.show()

# %%
# Column 'DMA'
df['DMA'].unique
sns.distplot(df['DMA'])
plt.show()
df['DMA'].isna().sum()

# Fillining NaNs with the mean
df['DMA'] = df['DMA'].fillna(np.mean(df['DMA']))
sns.distplot(df['DMA'])
# plt.show()
# Out:
# <AxesSubplot:xlabel='DMA', ylabel='Density'>

# %%
# Column 'MSA'
df['MSA'].unique
sns.distplot(df['MSA'])
plt.show()
df['MSA'].isna().sum()

# Fillining NaNs with the mean
df['MSA'] = df['MSA'].fillna(np.mean(df['MSA']))
sns.distplot(df['MSA'])
plt.show()

# %%
# 2. Dealing with the rest of numeric columns
sum_na = pd.DataFrame(df.isna().sum()/len(df)).reset_index()
sum_na.columns = ['column_name', 'nans_percentage']
sum_na.sort_values(by = ['nans_percentage'], ascending = False).head(10)
# Out:
#     column_name  nans_percentage
# 14          AGE         0.248030
# 353    ADATE_18         0.222855
# 352    ADATE_16         0.213432
# 351    ADATE_14         0.197742
# 348     ADATE_9         0.117857
# 349    ADATE_11         0.109232
# 369    NEXTDATE         0.104526
# 370     TIMELAG         0.104526
# 350    ADATE_12         0.093521
# 346     ADATE_7         0.093007

# %%
adate_columns = df.filter(like='ADATE')
adate_columns
# Out:
#        ADATE_2  ADATE_3  ADATE_4  ADATE_6  ADATE_7  ADATE_8  ADATE_9  \
# 0         9706   9606.0   9604.0   9603.0   9602.0   9601.0   9511.0
# 1         9706   9606.0   9604.0   9603.0   9602.0   9601.0   9511.0
# 2         9706   9606.0   9604.0   9603.0   9602.0   9601.0   9511.0
# 3         9706   9606.0   9604.0   9603.0   9602.0   9601.0   9511.0
# 4         9706   9606.0   9604.0   9603.0   9512.0   9601.0   9511.0
# ...        ...      ...      ...      ...      ...      ...      ...
# 95407     9706   9606.0   9604.0   9603.0   9601.0   9512.0      NaN
# 95408     9706      NaN      NaN      NaN   9601.0   9601.0      NaN
# 95409     9706   9606.0   9604.0   9603.0      NaN   9601.0   9511.0
# 95410     9706   9606.0   9609.0   9603.0   9602.0   9601.0   9511.0
# 95411     9706   9606.0   9604.0   9603.0   9602.0   9601.0   9511.0
#
#        ADATE_11  ADATE_12  ADATE_14  ADATE_16  ADATE_18  MAXADATE
# 0        9510.0    9508.0    9506.0    9503.0    9501.0      9702
# ...

# %%
df['ADATE_2'].fillna(9706, inplace=True)
df['ADATE_3'].fillna(9606.0, inplace=True)
df['ADATE_4'].fillna(9604.0, inplace=True)
df['ADATE_6'].fillna(9603.0, inplace=True)
df['ADATE_7'].fillna(9602.0, inplace=True)
df['ADATE_8'].fillna(9601.0, inplace=True)
df['ADATE_9'].fillna(9511.0, inplace=True)
df['ADATE_14'].fillna(9506.0, inplace=True)
df['ADATE_16'].fillna(9503.0, inplace=True)

# %%
sum_na = pd.DataFrame(df.isna().sum()/len(df)).reset_index()
sum_na.columns = ['column_name', 'nans_percentage']
sum_na.sort_values(by = ['nans_percentage'], ascending = False).head(10)
# Out:
#     column_name  nans_percentage
# 14          AGE         0.248030
# 353    ADATE_18         0.222855
# 349    ADATE_11         0.109232
# 369    NEXTDATE         0.104526
# 370     TIMELAG         0.104526
# 350    ADATE_12         0.093521
# 383    GEOCODE2         0.001383
# 259       EIC13         0.000000
# 258       EIC12         0.000000
# 257       EIC11         0.000000

# %%
# The column 'age' is difficult to fill due to the high amount of NaNs - maybe Regression Impution (in the future) can help here
